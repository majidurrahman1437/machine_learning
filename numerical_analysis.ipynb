# %%
print("This code is intended to perform numerical analysis.\nHere, we have assumed x as independent variable and y as dependent variable.\n")
num_of_data = int(input("Enter the number of data points: "))
x = list()
y = list()
apparent_y = list()
sum_of_all_x = 0
sum_of_all_y = 0
x_prod_y = 0
x_prod_x = 0
for i in range(num_of_data):
    print("X[", i,"] = ")
    x.append(float(input())) 
    sum_of_all_x = sum_of_all_x + x[i]
    x_prod_x = x_prod_x + (x[i] * x[i]) 
    print("Y[", i,"] = ")
    y.append(float(input())) 
    sum_of_all_y = sum_of_all_y + y[i]
    x_prod_y = x_prod_y + (x[i] * y[i])
    #print("Apparent_Y[", i,"] = ")
    #apparent_y.append(float(input()))
    

print(x)
print(y)
mean_x = sum_of_all_x / num_of_data
square_of_mean_x = mean_x * mean_x
mean_y = sum_of_all_y / num_of_data
mean_xy = x_prod_y / num_of_data
mean_x_square = x_prod_x / num_of_data

#m denotes the tangent of straight line
m = ((mean_x * mean_y) - mean_xy) / (square_of_mean_x - mean_x_square)

#c denotes the intercept
c = mean_y - (m * mean_x)

numerator_of_r_square = 0
denominator_of_r_square = 0
for j in range(num_of_data):
    apparent_y.append( (m * x[j] ) + c )
    numerator_of_r_square = numerator_of_r_square + ((apparent_y[j] - mean_y) * (apparent_y[j] - mean_y))
    denominator_of_r_square = denominator_of_r_square + ((y[j] - mean_y) * (y[j] - mean_y))


#R_square denotes the how well fit is the hypothesis

print("List of Apparent_y = ", apparent_y)
r_square = numerator_of_r_square / denominator_of_r_square

print("Mean of X = ", mean_x, "\n")
print("Mean of Y = ", mean_y, "\n")
print("Mean of XY = ", mean_xy, "\n")
print("Square of Mean-X = ", square_of_mean_x, "\n")
print("Mean of X-square = ", mean_x_square, "\n")
print("The value of m = ", m)
print("The value of c = ", c)
print("The value of R_square = ", r_square)
# Out:
# This code is intended to perform numerical analysis.
# Here, we have assumed x as independent variable and y as dependent variable.
#
# Enter the number of data point: 5
# X[ 0 ] =
# 6
# Y[ 0 ] =
# 350
# X[ 1 ] =
# 8
# Y[ 1 ] =
# 775
# X[ 2 ] =
# 12
# Y[ 2 ] =
# 1150
# X[ 3 ] =
# 14
# Y[ 3 ] =
# 1395
# X[ 4 ] =
# 18
# Y[ 4 ] =
# 1675
# [6.0, 8.0, 12.0, 14.0, 18.0]
# [350.0, 775.0, 1150.0, 1395.0, 1675.0]
# List of Apparent_y =  [468.59649122807036, 683.0263157894738, 1111.8859649122808, 1326.3157894736842, 1755.175438596491]
# Mean of X =  11.6
#
# Mean of Y =  1069.0
#
# Mean of XY =  14356.0
#
# Square of Mean-X =  134.56
#
# Mean of X-square =  152.8
#
# The value of m =  107.21491228070172
# The value of c =  -174.69298245614004
# The value of R_square =  0.9675832392966128
